# %%
import docx

# %%
doc = docx.Document('/Users/mqgao/Downloads/word-with-table.docx')

# %%
doc.tables

# %%
doc.paragraphs

# %%
dir(doc.paragraphs[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_element',
#  '_insert_paragraph_before',
#  '_p',
#  '_parent',
#  'add_run',
#  'alignment',
#  'clear',
#  'insert_paragraph_before',
#  'paragraph_format',
#  'part',
#  'runs',
#  'style',
#  'text']

# %%
for p in doc.paragraphs:
    print(p.text)
# Out:
# PCB外协加工单
#                                                        编目：F0001848

# %%
import docx2txt

# %%
text = docx2txt.process("/Users/mqgao/Downloads/word-with-table.docx")

# %%
print(text)
# Out:
# PCB外协加工单
#
#                                                        编目：F0001848
#
# 板名: M_INT00150
#
# 版本：VA
#
# PCB号: 03.10.608640
#
# 板厚（mm）：1.6
#
# 层数：6
#
# 板面积  长：（mm）：272.80
#
# 宽（mm）: 141.22
#
# 表面处理方式：ENIG
#
# 是否有特殊工艺要求：无
#
# 板材：刚性板|中TG-FR4(TG150)
#
# 是否有特殊板材：无
#
# 厚径比：8::1
#
# 拼版方式: 2*1
#
# 加工数量（块）：30
#
# 要求加工时间：  2018-06-16(加急）     前到我司
#
# 阻抗测试表是否要求提供：是
#
# 油墨颜色：绿色
#
# 单板类型：刚性板
#
# 外协加工单位名称: 广州兴森快捷电路科技有限公司
#
# 联系人姓名: 张高明
#
#
#
# 传真: 021-61285620
#
#
#
# 电话: 0512-62386403/18626285861
#
# 邮件地址: sales6.sh@chinafastprint.com;zhanggm@chinafastprint.com,sz.sales001@chinafastprint.com
#
#
#
# 其他说明:
#
# 1）请在单板上印上贵司“LOGO”;
#
# 2）其他要求参考光绘文件DRILL层的文字说明和表格;
#
# 3）如果有“PCB打样研发特殊要求”，则按照特殊要求加工;
#
# Email:  jiangkaizhong@kedacom.com;
#
# 电话:  0512-68418188-6543
#
# 手机:   13606212289
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 项目经理签字：         日期：
#
# PCB QA签字：           日期：
#
# 项目QA签字：          日期：
#
# 开发部经理签字：       日期：
#
#
#
# 编号：KDC-YFYJ007/01					           版本：B/0			          实施日期：2007/01/23

# %%
from openpyxl import load_workbook

# %%
wb = load_workbook(filename = '/Users/mqgao/Downloads/HIKVISION-PCB.xlsx')

# %%
wb.sheetnames
# Out:
# ['Sheet1']

# %%
shape = list(list(wb[wb.sheetnames[0]])[15])[2]

# %%
list(list(wb[wb.sheetnames[0]])[0])[0].border
# Out:
# <openpyxl.styles.borders.Border object>
# Parameters:
# outline=True, diagonalUp=False, diagonalDown=False, start=None, end=None, left=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, right=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, top=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, bottom=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, diagonal=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, vertical=None, horizontal=None

# %%
shape.border
# Out:
# <openpyxl.styles.borders.Border object>
# Parameters:
# outline=True, diagonalUp=False, diagonalDown=False, start=None, end=None, left=<openpyxl.styles.borders.Side object>
# Parameters:
# style='thin', color=<openpyxl.styles.colors.Color object>
# Parameters:
# rgb=None, indexed=None, auto=True, theme=None, tint=0.0, type='auto', right=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, top=<openpyxl.styles.borders.Side object>
# Parameters:
# style='thin', color=<openpyxl.styles.colors.Color object>
# Parameters:
# rgb=None, indexed=None, auto=True, theme=None, tint=0.0, type='auto', bottom=<openpyxl.styles.borders.Side object>
# Parameters:
# style='thin', color=<openpyxl.styles.colors.Color object>
# Parameters:
# rgb=None, indexed=None, auto=True, theme=None, tint=0.0, type='auto', diagonal=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, vertical=None, horizontal=None

# %%
for i, row in enumerate(wb[wb.sheetnames[0]]): 
    for j, column in enumerate(row):
        if j == 15 and 2 <= i <= 3: print()
        print('\t \t x: {} , y: {} : {}'.format(j, i, column.value))
# Out:
# 	 	 x: 0 , y: 0 : JUST
# 	 	 x: 1 , y: 0 : FOR
# 	 	 x: 2 , y: 0 : EXAMPLE
# 	 	 x: 3 , y: 0 : None
# 	 	 x: 4 , y: 0 : None
# 	 	 x: 5 , y: 0 : None
# 	 	 x: 6 , y: 0 : None
# 	 	 x: 7 , y: 0 : None
# 	 	 x: 0 , y: 1 : None
# 	 	 x: 1 , y: 1 : None
# 	 	 x: 2 , y: 1 : None
# 	 	 x: 3 , y: 1 : None
# 	 	 x: 4 , y: 1 : None
# 	 	 x: 5 , y: 1 : None
# 	 	 x: 6 , y: 1 : None
# 	 	 x: 7 , y: 1 : None
# 	 	 x: 0 , y: 2 : None
# 	 	 x: 1 , y: 2 : None
# 	 	 x: 2 , y: 2 : None
# 	 	 x: 3 , y: 2 : None
# 	 	 x: 4 , y: 2 : None
# 	 	 x: 5 , y: 2 : None
# 	 	 x: 6 , y: 2 : None
# 	 	 x: 7 , y: 2 : None
# 	 	 x: 0 , y: 3 : None
# 	 	 x: 1 , y: 3 : None
# 	 	 x: 2 , y: 3 : None
# 	 	 x: 3 , y: 3 : None
# 	 	 x: 4 , y: 3 : None
# 	 	 x: 5 , y: 3 : None
# 	 	 x: 6 , y: 3 : None
# 	 	 x: 7 , y: 3 : None
# 	 	 x: 0 , y: 4 : PCB-DS-221M5REV1.0(180525106)加工单
# 	 	 x: 1 , y: 4 : None
# 	 	 x: 2 , y: 4 : None
# 	 	 x: 3 , y: 4 : None
# 	 	 x: 4 , y: 4 : None
# 	 	 x: 5 , y: 4 : None
# ...

# %%
import olefile
